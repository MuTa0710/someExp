# %% [markdown]
# # 生成式推荐
#
# ## 核心概念
#
# ### 传统推荐系统
#
# 首先说说传统推荐系统，传统推荐系统的主要目标，是根据用户的偏好推送用户可能感兴趣的item，这里的item可能是视频，商品，文章等等。
#
# 传统推荐系统的做法是，输入用户的行为序列，在item列表中召回与之相关的item，然后进行粗排，精排，最终版得到推送给用户的item。
#
# 也就是说，传统推荐系统是漏斗式的筛选。
#
# ### 生成式推荐系统
#
# 生成式推荐的概念是基于传统推荐而提出的。旨在通过大语言模型的NTP能力，直接推理出用户感兴趣的物品并进行推送。
#
# ## 生成式推荐的论文调研
#
# ### 快手 OneRec
